# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings

warnings.filterwarnings('ignore')

# %%
titles = pd.read_csv('../data/titles.csv')
credits = pd.read_csv('../data/credits.csv')
titles
credits
# Out:
#        person_id         id                name                  character  \
# 0           3180    tm82169  Sylvester Stallone      Robert "Rocky" Balboa
# 1           7748    tm82169         Talia Shire  Adrianna "Adrian" Pennino
# 2           7749    tm82169          Burt Young             Paulie Pennino
# 3           7750    tm82169       Carl Weathers               Apollo Creed
# 4           7751    tm82169    Burgess Meredith            Mickey Goldmill
# ...          ...        ...                 ...                        ...
# 81350     449518  tm1072700       Kayode Olaiya                 Uncle Adio
# 81351    2722717  tm1072700         Tolu Osaile                       Sade
# 81352    2722797  tm1072700      Eniola Oyetola               Officer Meks
# 81353     866314  tm1072700         Tope Tedela               Officer Jack
# 81354    1807691  tm1072700      Taiwo Egunjobi                        NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# ...

# %%
titles.shape
# Out:
# (6137, 15)

# %%
credits
# Out:
#        person_id         id                name                  character  \
# 0           3180    tm82169  Sylvester Stallone      Robert "Rocky" Balboa
# 1           7748    tm82169         Talia Shire  Adrianna "Adrian" Pennino
# 2           7749    tm82169          Burt Young             Paulie Pennino
# 3           7750    tm82169       Carl Weathers               Apollo Creed
# 4           7751    tm82169    Burgess Meredith            Mickey Goldmill
# ...          ...        ...                 ...                        ...
# 81350     449518  tm1072700       Kayode Olaiya                 Uncle Adio
# 81351    2722717  tm1072700         Tolu Osaile                       Sade
# 81352    2722797  tm1072700      Eniola Oyetola               Officer Meks
# 81353     866314  tm1072700         Tope Tedela               Officer Jack
# 81354    1807691  tm1072700      Taiwo Egunjobi                        NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# ...

# %%
titles
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 1       tm82169                                Rocky  MOVIE
# 2       tm17823                               Grease  MOVIE
# 3      tm191099                            The Sting  MOVIE
# 4       tm69975                             Rocky II  MOVIE
# ...         ...                                  ...    ...
# 6132  tm1303784                        عبود في البيت  MOVIE
# 6133  tm1260999                              Sweetie  MOVIE
# 6134  tm1310286            Sommore: Queen Chandelier  MOVIE
# 6135  tm1072700                         All Na Vibes  MOVIE
# 6136   tm561709                      Going to Heaven  MOVIE
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     When world heavyweight boxing champion, Apollo...          1976
# ...

# %%
df = titles.merge(credits, on="id", how="left")

# %%
df
# Out:
#               id                                title   type  \
# 0       ts300399  Five Came Back: The Reference Films   SHOW
# 1        tm82169                                Rocky  MOVIE
# 2        tm82169                                Rocky  MOVIE
# 3        tm82169                                Rocky  MOVIE
# 4        tm82169                                Rocky  MOVIE
# ...          ...                                  ...    ...
# 81699  tm1072700                         All Na Vibes  MOVIE
# 81700  tm1072700                         All Na Vibes  MOVIE
# 81701  tm1072700                         All Na Vibes  MOVIE
# 81702  tm1072700                         All Na Vibes  MOVIE
# 81703   tm561709                      Going to Heaven  MOVIE
#
#                                              description  release_year  \
# 0      This collection includes 12 World War II-era p...          1945
# 1      When world heavyweight boxing champion, Apollo...          1976
# ...

# %%
df.shape
# Out:
# (81704, 19)

# %%
df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score', 'person_id', 'name', 'character', 'role'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81704 entries, 0 to 81703
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    81704 non-null  object
#  1   title                 81704 non-null  object
#  2   type                  81704 non-null  object
#  3   description           81650 non-null  object
#  4   release_year          81704 non-null  int64
#  5   age_certification     47683 non-null  object
#  6   runtime               81704 non-null  int64
#  7   genres                81704 non-null  object
#  8   production_countries  81704 non-null  object
#  9   seasons               17032 non-null  float64
#  10  imdb_id               78418 non-null  object
#  11  imdb_score            77938 non-null  float64
#  12  imdb_votes            77863 non-null  float64
#  13  tmdb_popularity       81615 non-null  float64
#  14  tmdb_score            80664 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# title                       0
# type                        0
# description                54
# release_year                0
# age_certification       34021
# runtime                     0
# genres                      0
# production_countries        0
# seasons                 64672
# imdb_id                  3286
# imdb_score               3766
# imdb_votes               3841
# tmdb_popularity            89
# tmdb_score               1040
# person_id                 349
# name                      349
# character               11172
# role                      349
# dtype: int64

# %%
df.duplicated(subset='id').sum()
# Out:
# np.int64(75567)

# %%
#Shows duplicated row
df[df.duplicated(subset='id', keep= False)].sort_values('id')
# Out:
#               id                      title   type  \
# 77877  tm1000037               Je suis Karl  MOVIE
# 77872  tm1000037               Je suis Karl  MOVIE
# 77874  tm1000037               Je suis Karl  MOVIE
# 77875  tm1000037               Je suis Karl  MOVIE
# 77876  tm1000037               Je suis Karl  MOVIE
# ...          ...                        ...    ...
# 7622     ts98353  DreamWorks Spooky Stories   SHOW
# 1398       ts987               Danger Mouse   SHOW
# 1397       ts987               Danger Mouse   SHOW
# 1396       ts987               Danger Mouse   SHOW
# 1399       ts987               Danger Mouse   SHOW
#
#                                              description  release_year  \
# 77877  After most of her family is murdered in a terr...          2021
# 77872  After most of her family is murdered in a terr...          2021
# 77874  After most of her family is murdered in a terr...          2021
# ...

# %%
#Keeping the real dataset unchanged
df_work = df.copy()

# %%
df_work
# Out:
#               id                                title   type  \
# 0       ts300399  Five Came Back: The Reference Films   SHOW
# 1        tm82169                                Rocky  MOVIE
# 2        tm82169                                Rocky  MOVIE
# 3        tm82169                                Rocky  MOVIE
# 4        tm82169                                Rocky  MOVIE
# ...          ...                                  ...    ...
# 81699  tm1072700                         All Na Vibes  MOVIE
# 81700  tm1072700                         All Na Vibes  MOVIE
# 81701  tm1072700                         All Na Vibes  MOVIE
# 81702  tm1072700                         All Na Vibes  MOVIE
# 81703   tm561709                      Going to Heaven  MOVIE
#
#                                              description  release_year  \
# 0      This collection includes 12 World War II-era p...          1945
# 1      When world heavyweight boxing champion, Apollo...          1976
# ...

# %%
df[df.duplicated(subset='id', keep=False)].sort_values('id')
# Out:
#               id                      title   type  \
# 77877  tm1000037               Je suis Karl  MOVIE
# 77872  tm1000037               Je suis Karl  MOVIE
# 77874  tm1000037               Je suis Karl  MOVIE
# 77875  tm1000037               Je suis Karl  MOVIE
# 77876  tm1000037               Je suis Karl  MOVIE
# ...          ...                        ...    ...
# 7622     ts98353  DreamWorks Spooky Stories   SHOW
# 1398       ts987               Danger Mouse   SHOW
# 1397       ts987               Danger Mouse   SHOW
# 1396       ts987               Danger Mouse   SHOW
# 1399       ts987               Danger Mouse   SHOW
#
#                                              description  release_year  \
# 77877  After most of her family is murdered in a terr...          2021
# 77872  After most of her family is murdered in a terr...          2021
# 77874  After most of her family is murdered in a terr...          2021
# ...

# %%
df_work = df_work.drop_duplicates(subset='id', keep='first')

# %%
df_work.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_work[df_work.duplicated(subset='id', keep=False)].sort_values('id')
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score, person_id, name, character, role]
# Index: []

# %%
df_work.shape
# Out:
# (6137, 14)

# %%
#Drop unnecessary columns 
df_work = df_work.drop(columns=[
    'description',
    'imdb_id', 
    'character',
    'person_id', 
    'seasons', 
])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 2
#       1 #Drop unnecessary columns
# ----> 2 df_work = df_work.drop(columns=[
#       3     'description',
#       4     'imdb_id',
#       5     'character',
#       6     'person_id',
#       7     'seasons',
#       8     'id',
#       9 ])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
# ...

# %%
df_work
# Out:
#               id                                title   type  release_year  \
# 0       ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1        tm82169                                Rocky  MOVIE          1976
# 51       tm17823                               Grease  MOVIE          1978
# 99      tm191099                            The Sting  MOVIE          1973
# 142      tm69975                             Rocky II  MOVIE          1979
# ...          ...                                  ...    ...           ...
# 81649  tm1303784                        عبود في البيت  MOVIE          2023
# 81655  tm1260999                              Sweetie  MOVIE          2023
# 81685  tm1310286            Sommore: Queen Chandelier  MOVIE          2023
# 81687  tm1072700                         All Na Vibes  MOVIE          2023
# 81703   tm561709                      Going to Heaven  MOVIE          2023
#
# ...
